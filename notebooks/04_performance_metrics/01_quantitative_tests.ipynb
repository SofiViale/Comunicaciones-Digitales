# %% [markdown]
# # ¿Qué hace este Notebook?

# %% [markdown]
# Aquí se realizan las pruebas que como resultado generan las métricas de rendimiento cualitativas para distintos canales LoRa. Permite elegir canales tanto simulados como reales, modificar parámetros LoRa, de sistema o de SDRs.
#
# > Cada celda tiene una razón de ser explicada arriba.

# %% [markdown]
# ### 1. Cambia la dirección de referencia del Notebook para poder importar nuestro Source Code

# %%
#------------------- Change working directory to project root -------------------#
from pathlib import Path, os

cur = Path().resolve()
while not (cur / "src").is_dir():
    if cur == cur.parent: raise RuntimeError("No 'src' dir")
    cur = cur.parent

os.chdir(cur)
print(f"[INFO] Changed working directory to project root: {cur}")
# Out:
# [INFO] Changed working directory to project root: /home/fernando/Documents/LoRaPriv

# %% [markdown]
# ### 2. Importa Librerias Internas y Externas

# %%
# -------------------------------------- External Dependencies -----------------------------------
import numpy as np
from typing import Union
from datetime import datetime
from typing import Callable
import matplotlib.pyplot as plt
import random
from collections import defaultdict
import time
# ----------------------------------------- Local Imports ----------------------------------------
from src.core                  import LoRaPhyParams, LoRaFrameParams
from src.mod                   import LoRaModulator
from src.demod                 import LoRaDemodulator
from src.sync                  import DechirpBasedSynchronizer, CorrelationBasedSynchronizer
from src.core.vpn_utils        import VPNKeepAlive

import src.core.params as params
import src.core.sdr_utils as sdr_utils
import src.core.snr_utils as snr_utils
import src.core.perf_metrics_utils as perf_utils

# %% [markdown]
# ### 3. Define Constantes o Variables con poco cambio

# %%
SIMULATIONS_BUFFER_SIZE = 2**20             # Tamaño del buffer al simular transmisiones SDR (Cuando no se simula, el tamaño del buffer ya está dentro del perfil LoRa)
DEFAULT_MAX_TRANSCEIVE_ATTEMPTS = 5_000     # Máximo número de ejecuciones de canal (por si tarda demasiado en converger al indicador de confianza)
AUTO_DELETE_TMP_LOG = False                 # Eliminar el log temporal al finalizar
MOD_BACKEND = "numpy"
DEMOD_BACKEND = "cupy"

# %% [markdown]
# ### 4. Genera decoradores para clasificar los distintos canales de transmisión a evaluar

# %%
# Decorador para identificar el canal

def channel_fn_identifier(id_:str):
    """
    Decorator to identify the channel function by its ID.
    """
    def decorator(fn: Callable):
        fn.channel_id = id_
        return fn
    return decorator

# Decorador para identificar si el canal necesita ser sincronizado
def needs_sync(sync: bool):
    """
    Decorator to indicate if the channel function requires synchronization.
    """
    def decorator(fn: Callable):
        fn.needs_sync = sync
        return fn
    return decorator

# Decorador para identificar si el canal necesita un vpn
def needs_vpn(vpn: bool):
    """
    Decorator to indicate if the channel function requires a VPN.
    """
    def decorator(fn: Callable):
        fn.needs_vpn = vpn
        return fn
    return decorator

# %% [markdown]
# ### 5. Canales de Transmisión Simulados
#
# Estas funciones emulan matemáticamente las imperfecciones de un canal de radio real, permitiendo pruebas rápidas y controladas sin usar hardware.
#
# -   Canal AWGN (sim...awgn): Añade Ruido Aditivo Blanco Gaussiano, el tipo de interferencia electrónica más común, para simular la degradación de la señal a un SNR (Relación Señal/Ruido) específico.
#
# -   Canal con Eco (sim...echo): Simula un escenario de multitrayectoria, donde la señal principal se mezcla con un rebote más débil y retardado. Evalúa la robustez del sistema frente a la distorsión.
#
# -   Variantes sync y async: Las versiones sync procesan una trama completa (preámbulo + datos) para probar la sincronización, mientras que las async operan solo sobre los datos para aislar el rendimiento del demodulador.

# %%
# Funciones de simulación de canal SDR

@channel_fn_identifier("sim_sync_awgn")
@needs_sync(True)
@needs_vpn(False)
def sim_channel_sync_awgn(
    profile:snr_utils.LoRaProfile, 
    modulated_frame_waveform, 
    payload,
    reference_payload_waveform, 
    snr_db:float
    ) -> tuple[bool, np.ndarray]:
    """
    Simulates an SDR channel that needs synchronization and is rolled, returning the modulated frame with noise.
    """

    # Añade ruido blanco gaussiano al frame modulado
    noisy_frame, _, _ = snr_utils.generate_awgn(f"{snr_db}db", modulated_frame_waveform, reference_payload_waveform)

    # Repite el frame para que tenga el tamaño de un buffer
    buffer_size = SIMULATIONS_BUFFER_SIZE

    if len(noisy_frame) < buffer_size:
        reps = (buffer_size // len(noisy_frame)) + 1
        noisy_frame = np.tile(noisy_frame, reps)

    # Desplaza el frame para simular un canal real y un offset aleatorio
    noisy_frame = np.roll(noisy_frame, random.randint(0, len(noisy_frame) - 1))

    # Nos aseguramos de que el frame tenga el tamaño del buffer
    return noisy_frame[:buffer_size]

@channel_fn_identifier("sim_async_awgn")
@needs_sync(False)
@needs_vpn(False)
def sim_channel_async_awgn(
    profile:snr_utils.LoRaProfile,
    modulated_frame_waveform,
    payload,
    reference_payload_waveform,
    snr_db:float
    ) -> tuple[bool, np.ndarray]:
    """
    Simulates an SDR channel that doesn't need synchronization, returning the modulated payload with noise.
    """
    NEEDS_SYNC = False
    # Añade ruido blanco gaussiano al frame modulado
    noisy_frame, _, _ = snr_utils.generate_awgn(f"{snr_db}db", reference_payload_waveform)

    return noisy_frame

@channel_fn_identifier("sim_sync_echo")
@needs_sync(True)
@needs_vpn(False)
def sim_channel_sync_echo(
    profile:snr_utils.LoRaProfile,
    modulated_frame_waveform, 
    payload,
    reference_payload_waveform, 
    snr_db:float
    ) -> tuple[bool, np.ndarray]:
    """
    Simulates an SDR channel with multipath, returning the modulated end echoed frame with noise.
    """

    # Simula un canal con multipath, un "eco" del 20% de la señal retardada en una muestra.
    h = np.zeros(2, dtype=np.complex64)
    h[0] = np.sqrt(0.8)
    h[1] = np.sqrt(0.2)
# Funciones de simulación de canal SDR

@channel_fn_identifier("sim_sync_awgn")
@needs_sync(True)
@needs_vpn(False)
def sim_channel_sync_awgn(
    profile:snr_utils.LoRaProfile, 
    modulated_frame_waveform, 
    payload,
    reference_payload_waveform, 
    snr_db:float
    ) -> tuple[bool, np.ndarray]:
    """
    Simulates an SDR channel that needs synchronization and is rolled, returning the modulated frame with noise.
    """

    # Añade ruido blanco gaussiano al frame modulado
    noisy_frame, _, _ = snr_utils.generate_awgn(f"{snr_db}db", modulated_frame_waveform, reference_payload_waveform)

    # Repite el frame para que tenga el tamaño de un buffer
    buffer_size = SIMULATIONS_BUFFER_SIZE

    if len(noisy_frame) < buffer_size:
        reps = (buffer_size // len(noisy_frame)) + 1
        noisy_frame = np.tile(noisy_frame, reps)

    # Desplaza el frame para simular un canal real y un offset aleatorio
    noisy_frame = np.roll(noisy_frame, random.randint(0, len(noisy_frame) - 1))

    # Nos aseguramos de que el frame tenga el tamaño del buffer
    return noisy_frame[:buffer_size]

@channel_fn_identifier("sim_async_echo")
@needs_sync(False)
@needs_vpn(False)
def sim_channel_async_echo(
    profile:snr_utils.LoRaProfile,
    modulated_frame_waveform,
    payload,
    reference_payload_waveform,
    snr_db:float
    ) -> tuple[bool, np.ndarray]:
    """
    Simulates an SDR channel with multipath and no synchronization, returning the modulated echoed payload with noise.
    """

    # Simula un canal con multipath, un "eco" del 20% de la señal retardada en una muestra.
    h = np.zeros(2, dtype=np.complex64)
    h[0] = np.sqrt(0.8)
    h[1] = np.sqrt(0.2)

    convolved = np.convolve(reference_payload_waveform, h, mode="full")
    echoed_waveform = convolved[:len(reference_payload_waveform)]

    # Añade ruido blanco gaussiano al frame modulado
    noisy_frame, _, _ = snr_utils.generate_awgn(f"{snr_db}db", echoed_waveform)

    return noisy_frame

# %% [markdown]
# ### 5.b. Canal con Desalineamiento de Fase (sim_channel_async_awgn_phase_mis)
#
# Este canal simula una imperfección avanzada: los saltos de fase intra-símbolo, causados por inestabilidades en los osciladores del hardware. Su proceso es:
#
# -   Identifica el inicio de cada discontinuidad intra-símbolo LoRa en la señal.
#
# -   Introduce un error de fase aleatorio distinto para cada símbolo, rotando su fase.
#
# -   Añade ruido AWGN al final sobre la señal ya distorsionada.
#
# Es una prueba crítica para verificar que el demodulador es robusto ante las imperfecciones de los dispositivos de radio del mundo real.

# %%
@channel_fn_identifier("sim_async_awgn_phase_mis")
@needs_sync(False)
@needs_vpn(False)
def sim_channel_async_awgn_phase_mis(
    profile:snr_utils.LoRaProfile,
    modulated_frame_waveform,
    payload,
    reference_payload_waveform,
    snr_db:float
    ) -> tuple[bool, np.ndarray]:
    """
    Simulates an SDR channel that doesn't need synchronization, returning the modulated payload with noise
    and with misalignments in phase.
    """

    modulator = LoRaModulator(profile.phy_params, profile.frame_params, backend=MOD_BACKEND)

    # Averiguamos donde están las discontinuidades intra-simbolo al pasar de BW a 0
    _, start_indices_list = modulator.locate_discontinuities(payload, include_frame=False)
    
    # Convertimos la lista a un array de NumPy para poder hacer operaciones matemáticas
    start_indices = np.asarray(start_indices_list)

    sps = profile.phy_params.samples_per_symbol

    stop_indices = ((start_indices // sps) + 1) * sps
    distorted_waveform = reference_payload_waveform.copy()

    #print("Applying phase misalignments to the following ranges:")
    for start, stop in zip(start_indices, stop_indices):
        #print(f"  - From sample {start} to {stop}.")
        stop = min(stop, len(distorted_waveform))
        phase_misalignment = np.random.uniform(-np.pi, np.pi)
        phasor = np.exp(1j * phase_misalignment)
        distorted_waveform[start:stop] *= phasor

    noisy_frame, _, _ = snr_utils.generate_awgn(f"{snr_db}db", distorted_waveform)
    
    return noisy_frame

# %% [markdown]
# ### 6. Canales de Transmisión Reales (vía SDR)
#
# Estas funciones utilizan hardware de Radio Definida por Software (SDR) para realizar transmisiones y recepciones físicas.
#
# #### Canal con un solo SDR (`real_channel_single_sdr`):
# Usa un único dispositivo para transmitir y recibir. Es ideal para pruebas de "loopback" controladas, donde se conecta la salida a la entrada con atenuadores para fijar el SNR.
#
# <table>
#     <tr>
#     <td><img src="../../img/single_sdr_1.jpeg" width="350"></td>
#     <td><img src="../../img/single_sdr_2.jpeg" height="350"></td>
#     </tr>
# </table>
#
# #### Canal con SDR Dual (`real_channel_dual_sdr`):
# Emplea dos SDRs independientes, uno para transmitir y otro para recibir, simulando un enlace de comunicación más realista.
#
# <table>
#     <tr>
#     <td><img src="../../img/dual_sdr_1.jpeg" width="350"></td>
#     <td><img src="../../img/dual_sdr_2.jpeg" height="350"></td>
#     </tr>
# </table>
#
# Ambas funciones realizan un paso crítico: limpian los buffers de recepción del SDR antes de la captura final. Esto asegura que la señal analizada es fresca y no un remanente de operaciones anteriores.

# %%
# Funciones de canal SDR reales

@channel_fn_identifier("real_single_sdr")
@needs_sync(True)
@needs_vpn(True)
def real_channel_single_sdr(
    profile: snr_utils.LoRaProfile,
    modulated_frame_waveform,
    payload,
    reference_payload_waveform,
    snr_db: float
) -> tuple[bool, np.ndarray]:
    """
    Real SDR channel using a single SDR for both TX and RX.
    """
    sdr_norm = (2**15 - 1)

    tx_sdr_params: sdr_utils.SDRParams = profile.tx_sdr_params

    needed_tx_atten = profile.get_atten_for_snr(snr_db)
    if needed_tx_atten is None:
        raise ValueError("No se pudo determinar la atenuación necesaria para el SNR dado.")

    tx_sdr_params.tx_attenuation = needed_tx_atten
    tx_sdr_params.tx_cyclic_buffer = True

    txrx_sdr = sdr_utils.init_sdr(tx_sdr_params)
    txrx_sdr.tx(modulated_frame_waveform * sdr_norm)
    time.sleep(0.5)
    for _ in range(2):
        _unused = txrx_sdr.rx()
    received_signal = txrx_sdr.rx() / sdr_norm

    sdr_utils.soft_delete_sdr(txrx_sdr)
    return received_signal

@channel_fn_identifier("real_dual_sdr")
@needs_sync(True)
@needs_vpn(True)
def real_channel_dual_sdr(
    profile: snr_utils.LoRaProfile,
    modulated_frame_waveform,
    payload,
    reference_payload_waveform,
    snr_db: float
) -> tuple[bool, np.ndarray]:
    """
    Real SDR channel using two separate SDRs for TX and RX.
    """
    sdr_norm = (2**15 - 1)

    tx_sdr_params: sdr_utils.SDRParams = profile.tx_sdr_params
    rx_sdr_params: sdr_utils.SDRParams = profile.rx_sdr_params

    needed_tx_atten = profile.get_atten_for_snr(snr_db)
    if needed_tx_atten is None:
        raise ValueError("No se pudo determinar la atenuación necesaria para el SNR dado.")

    tx_sdr_params.tx_attenuation = needed_tx_atten
    tx_sdr_params.tx_cyclic_buffer = True

    tx_sdr = sdr_utils.init_sdr(tx_sdr_params)
    rx_sdr = sdr_utils.init_sdr(rx_sdr_params)

    tx_sdr.tx(modulated_frame_waveform * sdr_norm)
    time.sleep(profile.phy_params.sample_duration * profile.rx_sdr_params.rx_buffer_size)

    for _ in range(2):
        _unused = rx_sdr.rx()
    received_signal = rx_sdr.rx() / sdr_norm

    sdr_utils.soft_delete_sdr(tx_sdr)
    sdr_utils.soft_delete_sdr(rx_sdr)

    return received_signal

# %% [markdown]
# ### 7. Define en qué consiste una transcepción de una trama LoRa
# En este caso:
# 1. Genera payload.
# 2. Intenta transmitir a través del canal.
# 3. Determina errores de trama, de símbolo y de bit a partir de lo recibido.

# %%
from src.sync import SynchronizationError
class FrameError(Exception):
    """Custom exception for frame errors that contribute to FER but cannot arise in the Synchronizer."""
    pass

def transceive_lora_frame(
    profile: snr_utils.LoRaProfile,
    payload_syms_count:int, 
    snr_db:float,
    channel_fn: Callable[[snr_utils.LoRaProfile, np.ndarray, np.ndarray, float], tuple[bool, np.ndarray]],
    modulator: LoRaModulator,
    synchronizer: Union[DechirpBasedSynchronizer, CorrelationBasedSynchronizer],
    demodulator: LoRaDemodulator
) -> dict:
    """
    Transceive a LoRa frame with the given SNR and payload symbol count.

    • Uses the provided channel function to simulate or execute transmission.
    • Returns a dict with:
        - 'fer_err': 0/1 (frame failed?)
        - 'ser_err': int   (symbol errors in this frame, should be ignored if fer_err is 1)
        - 'ber_err': int   (bit errors in this frame, should be ignored if fer_err is 1)
    """

    # Preparación para transmitir
    payload = np.random.randint(0, modulator.phy_params.chips_per_symbol, size=payload_syms_count)
    modulated_frame = modulator.modulate(payload, include_frame=True)
    reference_payload = modulator.modulate(payload, include_frame=False)

    try:
        # Simula la transmisión del frame a través del canal
        received_iq_buffer = channel_fn(profile, modulated_frame, payload, reference_payload, snr_db) 
        needs_sync = channel_fn.needs_sync

    except Exception as e:

        print(f"[ERROR] Channel function failed. This shouldn't happen: {e}")

        raise
    
    try:
        if needs_sync:
            aligned_payload = synchronizer.run(received_iq_buffer) # Retorna el payload alineado o lanza SynchronizationError si falla
        else:
            aligned_payload = received_iq_buffer

        expected_samples = payload_syms_count * modulator.phy_params.samples_per_symbol
        if len(aligned_payload) != expected_samples:
            raise FrameError("Aligned payload is different to the expected value. Will contribute to FER.")

        demodulated_symbols = demodulator.demodulate(aligned_payload, padding=1)
        demodulator.backend.clear_memory() # Limpiar la memoria del demodulador (Si se usa cupy sirve)
        demodulated_symbols = demodulated_symbols.get() if hasattr(demodulated_symbols, 'get') else demodulated_symbols


        # Calcula Errores
        ser_err = np.sum(demodulated_symbols != np.asarray(payload))
        ber_err = sum(bin(m ^ dm).count('1') for m, dm in zip(payload, demodulated_symbols))

        return {
            'fer_err': 0,
            'ser_err': ser_err,
            'ber_err': ber_err,
            'error_type': None
        }

    except (SynchronizationError, FrameError) as e:
        return {
            'fer_err': 1,
            'ser_err': 0,
            'ber_err': 0,
            'error_type': type(e).__name__
        }

    except Exception as e:
        print(f"WEIRD ERROR: {e}")
        print(f"payload syms count: {payload_syms_count}")
        print(f"payload length: {len(payload)}")
        print(f"aligned payload length in symbols: {len(aligned_payload)*modulator.phy_params.samples_per_symbol}")
        print(f"demodulated symbols length: {len(demodulated_symbols)}")
        
        raise

# %% [markdown]
# ### 8. Define como se trata al resultado de un conjunto de transcepciones LoRa a un SNR específico
# Realiza transcepciones LoRa en bucle hasta que se cumpla algun límite o punto de satisfacción estadístico para un SNR dado y devuelve el resultado de evaluar ese punto de métrica de rendimiento.

# %%
def run_snr_point_metric(
    profile: snr_utils.LoRaProfile,
    snr_db: float,
    payload_syms_count: int,
    channel_fn: Callable[[snr_utils.LoRaProfile, np.ndarray, np.ndarray, float],  tuple[bool, np.ndarray]],
    vpn_guard: VPNKeepAlive,
    modulator: LoRaModulator,
    synchronizer: Union[DechirpBasedSynchronizer, CorrelationBasedSynchronizer],
    demodulator: LoRaDemodulator,
    rel_tol: float,  # Relative tolerance for confidence intervals
    max_transceive_attempts: int,
    tmp_log_path: Path
): 
    """
    Run a full transmission test at a given SNR point a number of times, collecting metrics.

    Returns performance metrics and flags whether the result is trustworthy.
    """
    print(f"\n[INFO] --- SNR target {snr_db:+.1f} dB ---")

    MIN_TRANSCEIVE_ATTEMPTS = max(100, max_transceive_attempts // 5)
    print(f"[INFO] Minimum transceive attempts: {MIN_TRANSCEIVE_ATTEMPTS}")

    frames     = 0
    fer_errs   = 0
    ser_errs   = 0
    ber_errs   = 0
    syms_total = 0

    error_counts = defaultdict(int)

    while True:
        vpn_guard.maybe_reconnect(channel_fn.needs_vpn)

        # Ejecuta una transcepción de frame LoRa, o en su defecto de un payload
        result = transceive_lora_frame(
            profile=profile,
            payload_syms_count=payload_syms_count,
            snr_db=snr_db,
            channel_fn=channel_fn,
            modulator=modulator,
            synchronizer=synchronizer,
            demodulator=demodulator
        )

        frames     += 1
        fer_errs   += result['fer_err']
        ser_errs   += result['ser_err']
        ber_errs   += result['ber_err']

        if result['fer_err'] == 0:
            syms_total += payload_syms_count

        if result['fer_err'] == 1 and result.get("error_type") is not None:
            error_counts[result["error_type"]] += 1

        perf_utils.log_frame_result(tmp_log_path, snr_db, result, frames, syms_total)
    
        # Computa puntos de confianza
        fer_point = perf_utils.SinglePerformancePoint.from_event_count(fer_errs, frames) if channel_fn.needs_sync else None
        ser_point = perf_utils.SinglePerformancePoint.from_event_count(ser_errs, syms_total) if syms_total else None
        ber_point = perf_utils.SinglePerformancePoint.from_event_count(ber_errs, syms_total * modulator.phy_params.spreading_factor) if syms_total else None
        
        fer_ok = (fer_point.is_trusted(2*rel_tol) if fer_point else True) and frames > MIN_TRANSCEIVE_ATTEMPTS
        ser_ok = (ser_point.is_trusted(rel_tol) if ser_point else True) and frames > MIN_TRANSCEIVE_ATTEMPTS
        ber_ok = (ber_point.is_trusted(rel_tol) if ber_point else True) and frames > MIN_TRANSCEIVE_ATTEMPTS
        
        # Heurísticas de parada
        if all([fer_ok, ser_ok, ber_ok]):
            print(f"[INFO] Trust criterion met.")
            print(f"[INFO] SER {ser_point}, BER {ber_point}, FER {fer_point}")
            break

        if frames >= max_transceive_attempts:
            print("[WARN] Trust criterion not met, but too many transceive attempts made. Moving on.")
            print(f"[INFO] SER {ser_point}, BER {ber_point}, FER {fer_point}")
            break

    print(f"[INFO] Total Frames: {frames} | Total FER Errors: {fer_errs}")
    if fer_errs > 0:
        print("[INFO] Synchronization Error Breakdown:")
        for error_type, count in sorted(error_counts.items()):
            print(f"  -> {error_type}: {count} occurrences ({count/fer_errs*100:.1f}%)")

    print(f"[INFO] Final SER {ser_point}, BER {ber_point}, FER {fer_point}")

    # Retorna los resultados
    return perf_utils.SNRPointPerformanceMetrics(
        snr_db=snr_db,
        ber=ber_point,
        ser=ser_point,
        fer=fer_point
    )

# %% [markdown]
# ### 9. Realiza el anterior procedimiento en bucle para varios SNR, para armar un perfil de rendimiento a partir de los resultados

# %%
# --- Notebook Configuration ------------------------------------------
def run_sdr_quantitative_test(
    profile: snr_utils.LoRaProfile,
    snr_points: np.ndarray,
    channel_fn: Callable[[snr_utils.LoRaProfile, np.ndarray, np.ndarray, float], tuple[bool, np.ndarray]],
    max_transceive_attempts: int = DEFAULT_MAX_TRANSCEIVE_ATTEMPTS,
    filename: str= None
):
    """ Runs a quantitative test for LoRa frames over SDR channels, measuring performance metrics at various SNR points. """
    print(f"[INFO] Running quantitative test for profile: {profile.name} over channel: {channel_fn.__name__}")

    payload_symbol_count = sdr_utils.optimize_payload_symbols( # Cuantos símbolos hay de payload por trama
        buffer_len=profile.rx_sdr_params.rx_buffer_size if not profile.is_simulation() else SIMULATIONS_BUFFER_SIZE,
        preamble_symbols=profile.frame_params.preamble_symbol_count,
        samples_per_symbol=profile.phy_params.samples_per_symbol,
        pad_samples=0
    )
    
    log_dir = Path("tmp_quant_logs")
    tmp_log_path = perf_utils.create_new_log_file(log_dir)


    vpn_guard = VPNKeepAlive()

    if channel_fn.needs_vpn:
        print(f"[INFO] Channel function {channel_fn.__name__} requires VPN. Connecting...")
        vpn_guard.reconnect()

    modulator = LoRaModulator(profile.phy_params, profile.frame_params, backend=MOD_BACKEND)
    demodulator = LoRaDemodulator(profile.phy_params, backend=DEMOD_BACKEND, fold_mode=profile.fold_mode)

    if profile.sync_params.sync_source == params.SyncSource.DECHIRPING:
        synchronizer = DechirpBasedSynchronizer(profile.phy_params, profile.frame_params, backend=DEMOD_BACKEND, fold_mode=profile.fold_mode, sync_params=profile.sync_params.source_params)
    else:
        synchronizer = CorrelationBasedSynchronizer(profile.phy_params, profile.frame_params, backend=DEMOD_BACKEND, fold_mode=profile.fold_mode, sync_params=profile.sync_params.source_params)


    results = []
    for snr_db in snr_points:
        print(f"\n[INFO] Running SNR point: {snr_db} dB")
        point = run_snr_point_metric(
            profile=profile,
            snr_db=snr_db,
            payload_syms_count=payload_symbol_count,
            channel_fn=channel_fn,
            vpn_guard=vpn_guard,
            modulator=modulator,
            demodulator=demodulator,
            synchronizer=synchronizer,
            rel_tol=0.05,
            max_transceive_attempts=max_transceive_attempts,
            tmp_log_path=tmp_log_path
        )
        
        results.append(point)

    if channel_fn.needs_vpn:
        vpn_guard.disconnect()

    perf_metrics = perf_utils.SNRPerformanceMetrics(
        profile=profile, 
        snr_points=results,
        channel_function=channel_fn.__name__
        )
    
    perf_metrics.save(filename=filename)
    print(f"[INFO] Saved performance metrics to {filename if filename else perf_metrics.auto_name()}")

    if AUTO_DELETE_TMP_LOG:
        tmp_log_path.unlink(missing_ok=True)
        print(f"[INFO] Deleted temporary log file: {tmp_log_path}")

    perf_utils.plot_snr_performance(perf_metrics)

# %%
# # elegimos perfil
# profile_name = "opa/dech/profile_20251103_085002OPA.json"

# # elegimos canal
# channel_fn = sim_channel_sync_awgn

# # Cargamos perfil
# profile = snr_utils.LoRaProfile.load(f"{profile_name}")

# # Definimos rango de puntos de SNR
# snr_points = np.arange(-15, -6, 2)  
# print(f"[INFO] SNR points: {snr_points}")

# # Corremos pruebas cuantitativas
# run_sdr_quantitative_test(
#     profile=profile,
#     snr_points=snr_points,
#     channel_fn=channel_fn,
#     max_transceive_attempts=2000,
#     filename=f"{channel_fn.channel_id}/{profile_name}" if hasattr(channel_fn, 'channel_id') else None
# )

# %%
# elegimos perfil
profile_name = "opa/dech/profile_20251103_085002OPA.json"

# elegimos canal
channel_fn = sim_channel_async_awgn_phase_mis

# Cargamos perfil
profile = snr_utils.LoRaProfile.load(f"{profile_name}")

# Definimos rango de puntos de SNR
snr_points = np.arange(-15, -5, 1)  
print(f"[INFO] SNR points: {snr_points}")

# Corremos pruebas cuantitativas
run_sdr_quantitative_test(
    profile=profile,
    snr_points=snr_points,
    channel_fn=channel_fn,
    max_transceive_attempts=2000,
    filename=f"{channel_fn.channel_id}/{profile_name}" if hasattr(channel_fn, 'channel_id') else None
)
# Out:
# [INFO] SNR points: [-15 -14 -13 -12 -11 -10  -9  -8  -7  -6]
# [INFO] Running quantitative test for profile: 085002OPA over channel: sim_channel_async_awgn_phase_mis
#
# [INFO] Running SNR point: -15 dB
#
# [INFO] --- SNR target -15.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(208642), total_trial_count=404609, p_hat=np.float64(0.5156632699717505), ci_low=np.float64(0.5141232476962241), ci_high=np.float64(0.5172029948281125), rel_half_width=np.float64(0.0029861998238279877), conf_level=0.95), BER SinglePerformancePoint(event_count=749248, total_trial_count=3236872, p_hat=0.2314728540393318, ci_low=0.23101369462435795, ci_high=0.23193265081948367, rel_half_width=0.001985019364235192, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(208642), total_trial_count=404609, p_hat=np.float64(0.5156632699717505), ci_low=np.float64(0.5141232476962241), ci_high=np.float64(0.5172029948281125), rel_half_width=np.float64(0.0029861998238279877), conf_level=0.95), BER SinglePerformancePoint(event_count=749248, total_trial_count=3236872, p_hat=0.2314728540393318, ci_low=0.23101369462435795, ci_high=0.23193265081948367, rel_half_width=0.001985019364235192, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -14 dB
#
# [INFO] --- SNR target -14.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(161808), total_trial_count=404609, p_hat=np.float64(0.3999120138207504), ci_low=np.float64(0.39840351648447936), ci_high=np.float64(0.40142241165961534), rel_half_width=np.float64(0.00377444921733349), conf_level=0.95), BER SinglePerformancePoint(event_count=541575, total_trial_count=3236872, p_hat=0.1673143083816722, ci_low=0.16690807980632125, ci_high=0.1677213266063314, rel_half_width=0.0024302966311614115, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(161808), total_trial_count=404609, p_hat=np.float64(0.3999120138207504), ci_low=np.float64(0.39840351648447936), ci_high=np.float64(0.40142241165961534), rel_half_width=np.float64(0.00377444921733349), conf_level=0.95), BER SinglePerformancePoint(event_count=541575, total_trial_count=3236872, p_hat=0.1673143083816722, ci_low=0.16690807980632125, ci_high=0.1677213266063314, rel_half_width=0.0024302966311614115, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -13 dB
#
# [INFO] --- SNR target -13.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(122060), total_trial_count=404609, p_hat=np.float64(0.3016739617754425), ci_low=np.float64(0.3002615931230356), ci_high=np.float64(0.303090096305898), rel_half_width=np.float64(0.004688013453689926), conf_level=0.95), BER SinglePerformancePoint(event_count=363637, total_trial_count=3236872, p_hat=0.11234210064531437, ci_low=0.11199854399838614, ci_high=0.11268657742136083, rel_half_width=0.003062224308707479, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(122060), total_trial_count=404609, p_hat=np.float64(0.3016739617754425), ci_low=np.float64(0.3002615931230356), ci_high=np.float64(0.303090096305898), rel_half_width=np.float64(0.004688013453689926), conf_level=0.95), BER SinglePerformancePoint(event_count=363637, total_trial_count=3236872, p_hat=0.11234210064531437, ci_low=0.11199854399838614, ci_high=0.11268657742136083, rel_half_width=0.003062224308707479, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -12 dB
#
# [INFO] --- SNR target -12.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(94446), total_trial_count=404609, p_hat=np.float64(0.23342535633166836), ci_low=np.float64(0.23212447942425193), ci_high=np.float64(0.23473129504341403), rel_half_width=np.float64(0.005583831294356331), conf_level=0.95), BER SinglePerformancePoint(event_count=242285, total_trial_count=3236872, p_hat=0.07485158511056353, ci_low=0.07456541326392252, ci_high=0.07513876607229483, rel_half_width=0.00382993097290733, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(94446), total_trial_count=404609, p_hat=np.float64(0.23342535633166836), ci_low=np.float64(0.23212447942425193), ci_high=np.float64(0.23473129504341403), rel_half_width=np.float64(0.005583831294356331), conf_level=0.95), BER SinglePerformancePoint(event_count=242285, total_trial_count=3236872, p_hat=0.07485158511056353, ci_low=0.07456541326392252, ci_high=0.07513876607229483, rel_half_width=0.00382993097290733, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -11 dB
#
# [INFO] --- SNR target -11.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(79099), total_trial_count=404609, p_hat=np.float64(0.19549490990066953), ci_low=np.float64(0.1942758279473035), ci_high=np.float64(0.1967197738937755), rel_half_width=np.float64(0.006250663886118), conf_level=0.95), BER SinglePerformancePoint(event_count=176039, total_trial_count=3236872, p_hat=0.05438553022794847, ci_low=0.05413900910531227, ci_high=0.05463310904307545, rel_half_width=0.004542567992738524, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(79099), total_trial_count=404609, p_hat=np.float64(0.19549490990066953), ci_low=np.float64(0.1942758279473035), ci_high=np.float64(0.1967197738937755), rel_half_width=np.float64(0.006250663886118), conf_level=0.95), BER SinglePerformancePoint(event_count=176039, total_trial_count=3236872, p_hat=0.05438553022794847, ci_low=0.05413900910531227, ci_high=0.05463310904307545, rel_half_width=0.004542567992738524, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -10 dB
#
# [INFO] --- SNR target -10.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(72253), total_trial_count=404609, p_hat=np.float64(0.17857487104834543), ci_low=np.float64(0.17739780894248733), ci_high=np.float64(0.17975803647703606), rel_half_width=np.float64(0.006608509698740728), conf_level=0.95), BER SinglePerformancePoint(event_count=148334, total_trial_count=3236872, p_hat=0.04582634098598894, ci_low=0.04559907796064353, ci_high=0.0460546820195707, rel_half_width=0.00497098447229798, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(72253), total_trial_count=404609, p_hat=np.float64(0.17857487104834543), ci_low=np.float64(0.17739780894248733), ci_high=np.float64(0.17975803647703606), rel_half_width=np.float64(0.006608509698740728), conf_level=0.95), BER SinglePerformancePoint(event_count=148334, total_trial_count=3236872, p_hat=0.04582634098598894, ci_low=0.04559907796064353, ci_high=0.0460546820195707, rel_half_width=0.00497098447229798, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -9 dB
#
# [INFO] --- SNR target -9.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(69010), total_trial_count=404609, p_hat=np.float64(0.17055972556220944), ci_low=np.float64(0.1694039141400578), ci_high=np.float64(0.17172179250133163), rel_half_width=np.float64(0.006794917011133509), conf_level=0.95), BER SinglePerformancePoint(event_count=138433, total_trial_count=3236872, p_hat=0.04276752370807372, ci_low=0.04254764575710577, ci_high=0.042988486927563054, rel_half_width=0.005153924429508901, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(69010), total_trial_count=404609, p_hat=np.float64(0.17055972556220944), ci_low=np.float64(0.1694039141400578), ci_high=np.float64(0.17172179250133163), rel_half_width=np.float64(0.006794917011133509), conf_level=0.95), BER SinglePerformancePoint(event_count=138433, total_trial_count=3236872, p_hat=0.04276752370807372, ci_low=0.04254764575710577, ci_high=0.042988486927563054, rel_half_width=0.005153924429508901, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -8 dB
#
# [INFO] --- SNR target -8.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(67520), total_trial_count=404609, p_hat=np.float64(0.16687715794754937), ci_low=np.float64(0.16573141896426527), ci_high=np.float64(0.16802922237357207), rel_half_width=np.float64(0.006884715192803718), conf_level=0.95), BER SinglePerformancePoint(event_count=134166, total_trial_count=3236872, p_hat=0.041449275720510416, ci_low=0.041232673607531585, ci_high=0.04166696623095075, rel_half_width=0.005238844537930786, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(67520), total_trial_count=404609, p_hat=np.float64(0.16687715794754937), ci_low=np.float64(0.16573141896426527), ci_high=np.float64(0.16802922237357207), rel_half_width=np.float64(0.006884715192803718), conf_level=0.95), BER SinglePerformancePoint(event_count=134166, total_trial_count=3236872, p_hat=0.041449275720510416, ci_low=0.041232673607531585, ci_high=0.04166696623095075, rel_half_width=0.005238844537930786, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -7 dB
#
# [INFO] --- SNR target -7.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(65419), total_trial_count=404609, p_hat=np.float64(0.16168449045868974), ci_low=np.float64(0.1605532980011517), ci_high=np.float64(0.1628221069589923), rel_half_width=np.float64(0.0070161613875397485), conf_level=0.95), BER SinglePerformancePoint(event_count=130343, total_trial_count=3236872, p_hat=0.040268197197788486, ci_low=0.04005458074774135, ci_high=0.04048290484865737, rel_half_width=0.005318391816899401, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(65419), total_trial_count=404609, p_hat=np.float64(0.16168449045868974), ci_low=np.float64(0.1605532980011517), ci_high=np.float64(0.1628221069589923), rel_half_width=np.float64(0.0070161613875397485), conf_level=0.95), BER SinglePerformancePoint(event_count=130343, total_trial_count=3236872, p_hat=0.040268197197788486, ci_low=0.04005458074774135, ci_high=0.04048290484865737, rel_half_width=0.005318391816899401, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -6 dB
#
# [INFO] --- SNR target -6.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(64936), total_trial_count=404609, p_hat=np.float64(0.16049074538628652), ci_low=np.float64(0.15936295530373348), ci_high=np.float64(0.16162498217881613), rel_half_width=np.float64(0.0070472190456781604), conf_level=0.95), BER SinglePerformancePoint(event_count=130112, total_trial_count=3236872, p_hat=0.04019683200324264, ci_low=0.03998339753939606, ci_high=0.0404113578373005, rel_half_width=0.00532330878550229, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(64936), total_trial_count=404609, p_hat=np.float64(0.16049074538628652), ci_low=np.float64(0.15936295530373348), ci_high=np.float64(0.16162498217881613), rel_half_width=np.float64(0.0070472190456781604), conf_level=0.95), BER SinglePerformancePoint(event_count=130112, total_trial_count=3236872, p_hat=0.04019683200324264, ci_low=0.03998339753939606, ci_high=0.0404113578373005, rel_half_width=0.00532330878550229, conf_level=0.95), FER None
# [INFO] Saved performance metrics to sim_async_awgn_phase_mis/opa/dech/profile_20251103_085002OPA.json

# %%
# elegimos perfil
profile_name = "fpa/dech/profile_20251117_085002FPA.json"

# elegimos canal
channel_fn = sim_channel_async_awgn_phase_mis

# Cargamos perfil
profile = snr_utils.LoRaProfile.load(f"{profile_name}")

# Definimos rango de puntos de SNR
snr_points = np.arange(-15, -5, 1)  
print(f"[INFO] SNR points: {snr_points}")

# Corremos pruebas cuantitativas
run_sdr_quantitative_test(
    profile=profile,
    snr_points=snr_points,
    channel_fn=channel_fn,
    max_transceive_attempts=2000,
    filename=f"{channel_fn.channel_id}/{profile_name}" if hasattr(channel_fn, 'channel_id') else None
)
# Out:
# [INFO] SNR points: [-15 -14 -13 -12 -11 -10  -9  -8  -7  -6]
# [INFO] Running quantitative test for profile: 085002FPA over channel: sim_channel_async_awgn_phase_mis
#
# [INFO] Running SNR point: -15 dB
#
# [INFO] --- SNR target -15.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(127055), total_trial_count=404609, p_hat=np.float64(0.31401921361116536), ci_low=np.float64(0.31259089162151327), ci_high=np.float64(0.315451067063288), rel_half_width=np.float64(0.004554140826103023), conf_level=0.95), BER SinglePerformancePoint(event_count=456339, total_trial_count=3236872, p_hat=0.14098147841496358, ci_low=0.14060279239700296, ci_high=0.14136101658477318, rel_half_width=0.002689091490225644, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(127055), total_trial_count=404609, p_hat=np.float64(0.31401921361116536), ci_low=np.float64(0.31259089162151327), ci_high=np.float64(0.315451067063288), rel_half_width=np.float64(0.004554140826103023), conf_level=0.95), BER SinglePerformancePoint(event_count=456339, total_trial_count=3236872, p_hat=0.14098147841496358, ci_low=0.14060279239700296, ci_high=0.14136101658477318, rel_half_width=0.002689091490225644, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -14 dB
#
# [INFO] --- SNR target -14.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(77474), total_trial_count=404609, p_hat=np.float64(0.19147868683098992), ci_low=np.float64(0.19026924513619126), ci_high=np.float64(0.19269398682685274), rel_half_width=np.float64(0.006331622936190534), conf_level=0.95), BER SinglePerformancePoint(event_count=256619, total_trial_count=3236872, p_hat=0.07927993445523951, ci_low=0.07898610605472474, ci_high=0.07957476145989358, rel_half_width=0.0037125119313840007, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(77474), total_trial_count=404609, p_hat=np.float64(0.19147868683098992), ci_low=np.float64(0.19026924513619126), ci_high=np.float64(0.19269398682685274), rel_half_width=np.float64(0.006331622936190534), conf_level=0.95), BER SinglePerformancePoint(event_count=256619, total_trial_count=3236872, p_hat=0.07927993445523951, ci_low=0.07898610605472474, ci_high=0.07957476145989358, rel_half_width=0.0037125119313840007, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -13 dB
#
# [INFO] --- SNR target -13.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(42635), total_trial_count=404609, p_hat=np.float64(0.10537333573894797), ci_low=np.float64(0.1044310239812731), ci_high=np.float64(0.10632314079354757), rel_half_width=np.float64(0.008978157514923897), conf_level=0.95), BER SinglePerformancePoint(event_count=123665, total_trial_count=3236872, p_hat=0.038205094300917675, ci_low=0.03799681448871498, ci_high=0.03841447021083975, rel_half_width=0.005465968999253768, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(42635), total_trial_count=404609, p_hat=np.float64(0.10537333573894797), ci_low=np.float64(0.1044310239812731), ci_high=np.float64(0.10632314079354757), rel_half_width=np.float64(0.008978157514923897), conf_level=0.95), BER SinglePerformancePoint(event_count=123665, total_trial_count=3236872, p_hat=0.038205094300917675, ci_low=0.03799681448871498, ci_high=0.03841447021083975, rel_half_width=0.005465968999253768, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -12 dB
#
# [INFO] --- SNR target -12.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(22765), total_trial_count=404609, p_hat=np.float64(0.056264195803850135), ci_low=np.float64(0.05555837791774496), ci_high=np.float64(0.05697843948688721), rel_half_width=np.float64(0.012619584700836276), conf_level=0.95), BER SinglePerformancePoint(event_count=55746, total_trial_count=3236872, p_hat=0.017222182403258453, ci_low=0.017081025812077596, ci_high=0.017364484896350087, rel_half_width=0.00822947631244635, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(22765), total_trial_count=404609, p_hat=np.float64(0.056264195803850135), ci_low=np.float64(0.05555837791774496), ci_high=np.float64(0.05697843948688721), rel_half_width=np.float64(0.012619584700836276), conf_level=0.95), BER SinglePerformancePoint(event_count=55746, total_trial_count=3236872, p_hat=0.017222182403258453, ci_low=0.017081025812077596, ci_high=0.017364484896350087, rel_half_width=0.00822947631244635, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -11 dB
#
# [INFO] --- SNR target -11.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(12847), total_trial_count=404609, p_hat=np.float64(0.03175164170841479), ci_low=np.float64(0.031215806650382545), ci_high=np.float64(0.03229636801557174), rel_half_width=np.float64(0.017015834568686612), conf_level=0.95), BER SinglePerformancePoint(event_count=26756, total_trial_count=3236872, p_hat=0.00826600495787291, ci_low=0.008167951935828349, ci_high=0.00836522513984897, rel_half_width=0.011932802183522124, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(12847), total_trial_count=404609, p_hat=np.float64(0.03175164170841479), ci_low=np.float64(0.031215806650382545), ci_high=np.float64(0.03229636801557174), rel_half_width=np.float64(0.017015834568686612), conf_level=0.95), BER SinglePerformancePoint(event_count=26756, total_trial_count=3236872, p_hat=0.00826600495787291, ci_low=0.008167951935828349, ci_high=0.00836522513984897, rel_half_width=0.011932802183522124, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -10 dB
#
# [INFO] --- SNR target -10.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(7364), total_trial_count=404609, p_hat=np.float64(0.018200287190843507), ci_low=np.float64(0.01779294836732692), ci_high=np.float64(0.01861677458092514), rel_half_width=np.float64(0.02263223115547006), conf_level=0.95), BER SinglePerformancePoint(event_count=14690, total_trial_count=3236872, p_hat=0.004538332068737967, ci_low=0.004465695056050921, ci_high=0.004612145089210181, rel_half_width=0.016134785967742628, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(7364), total_trial_count=404609, p_hat=np.float64(0.018200287190843507), ci_low=np.float64(0.01779294836732692), ci_high=np.float64(0.01861677458092514), rel_half_width=np.float64(0.02263223115547006), conf_level=0.95), BER SinglePerformancePoint(event_count=14690, total_trial_count=3236872, p_hat=0.004538332068737967, ci_low=0.004465695056050921, ci_high=0.004612145089210181, rel_half_width=0.016134785967742628, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -9 dB
#
# [INFO] --- SNR target -9.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(3960), total_trial_count=404609, p_hat=np.float64(0.009787226680573096), ci_low=np.float64(0.009488510260299005), ci_high=np.float64(0.010095251417287636), rel_half_width=np.float64(0.030996582422728933), conf_level=0.95), BER SinglePerformancePoint(event_count=7860, total_trial_count=3236872, p_hat=0.002428270255975522, ci_low=0.0023752401251711814, ci_high=0.002482481402922449, rel_half_width=0.022081825012550918, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(3960), total_trial_count=404609, p_hat=np.float64(0.009787226680573096), ci_low=np.float64(0.009488510260299005), ci_high=np.float64(0.010095251417287636), rel_half_width=np.float64(0.030996582422728933), conf_level=0.95), BER SinglePerformancePoint(event_count=7860, total_trial_count=3236872, p_hat=0.002428270255975522, ci_low=0.0023752401251711814, ci_high=0.002482481402922449, rel_half_width=0.022081825012550918, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -8 dB
#
# [INFO] --- SNR target -8.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(1995), total_trial_count=404609, p_hat=np.float64(0.004930686168622052), ci_low=np.float64(0.0047195068529343595), ci_high=np.float64(0.00515126601828991), rel_half_width=np.float64(0.043782868204346875), conf_level=0.95), BER SinglePerformancePoint(event_count=3783, total_trial_count=3236872, p_hat=0.0011687209132767685, ci_low=0.0011320873363632094, ci_high=0.0012065384959483133, rel_half_width=0.03185155614969, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(1995), total_trial_count=404609, p_hat=np.float64(0.004930686168622052), ci_low=np.float64(0.0047195068529343595), ci_high=np.float64(0.00515126601828991), rel_half_width=np.float64(0.043782868204346875), conf_level=0.95), BER SinglePerformancePoint(event_count=3783, total_trial_count=3236872, p_hat=0.0011687209132767685, ci_low=0.0011320873363632094, ci_high=0.0012065384959483133, rel_half_width=0.03185155614969, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -7 dB
#
# [INFO] --- SNR target -7.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(1539), total_trial_count=737579, p_hat=np.float64(0.0020865561519511806), ci_low=np.float64(0.001984980303432175), ci_high=np.float64(0.0021933184388830676), rel_half_width=np.float64(0.04992392254962112), conf_level=0.95), BER SinglePerformancePoint(event_count=2957, total_trial_count=5900632, p_hat=0.0005011327600162152, ci_low=0.0004833971602518702, ci_high=0.0005195187318357221, rel_half_width=0.03603992241764747, conf_level=0.95), FER None
# [INFO] Total Frames: 731 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(1539), total_trial_count=737579, p_hat=np.float64(0.0020865561519511806), ci_low=np.float64(0.001984980303432175), ci_high=np.float64(0.0021933184388830676), rel_half_width=np.float64(0.04992392254962112), conf_level=0.95), BER SinglePerformancePoint(event_count=2957, total_trial_count=5900632, p_hat=0.0005011327600162152, ci_low=0.0004833971602518702, ci_high=0.0005195187318357221, rel_half_width=0.03603992241764747, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -6 dB
#
# [INFO] --- SNR target -6.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [WARN] Trust criterion not met, but too many transceive attempts made. Moving on.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(1478), total_trial_count=2018000, p_hat=np.float64(0.000732408325074331), ci_low=np.float64(0.0006960212156169043), ci_high=np.float64(0.0007706962395297697), rel_half_width=np.float64(0.05097909277948656), conf_level=0.95), BER SinglePerformancePoint(event_count=2947, total_trial_count=16144000, p_hat=0.0001825445986124876, ci_low=0.00017607242801536058, ci_high=0.00018925463190980275, rel_half_width=0.03610680347334142, conf_level=0.95), FER None
# [INFO] Total Frames: 2000 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(1478), total_trial_count=2018000, p_hat=np.float64(0.000732408325074331), ci_low=np.float64(0.0006960212156169043), ci_high=np.float64(0.0007706962395297697), rel_half_width=np.float64(0.05097909277948656), conf_level=0.95), BER SinglePerformancePoint(event_count=2947, total_trial_count=16144000, p_hat=0.0001825445986124876, ci_low=0.00017607242801536058, ci_high=0.00018925463190980275, rel_half_width=0.03610680347334142, conf_level=0.95), FER None
# [INFO] Saved performance metrics to sim_async_awgn_phase_mis/fpa/dech/profile_20251117_085002FPA.json

# %%
# elegimos perfil
profile_name = "cpa/dech/profile_20251103_085002CPA.json"

# elegimos canal
channel_fn = sim_channel_async_awgn_phase_mis

# Cargamos perfil
profile = snr_utils.LoRaProfile.load(f"{profile_name}")

# Definimos rango de puntos de SNR
snr_points = np.arange(-15, -5, 1)  
print(f"[INFO] SNR points: {snr_points}")

# Corremos pruebas cuantitativas
run_sdr_quantitative_test(
    profile=profile,
    snr_points=snr_points,
    channel_fn=channel_fn,
    max_transceive_attempts=2000,
    filename=f"{channel_fn.channel_id}/{profile_name}" if hasattr(channel_fn, 'channel_id') else None
)
# Out:
# [INFO] SNR points: [-15 -14 -13 -12 -11 -10  -9  -8  -7  -6]
# [INFO] Running quantitative test for profile: 085002CPA over channel: sim_channel_async_awgn_phase_mis
#
# [INFO] Running SNR point: -15 dB
#
# [INFO] --- SNR target -15.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(127511), total_trial_count=404609, p_hat=np.float64(0.31514622759256466), ci_low=np.float64(0.31371650827880543), ci_high=np.float64(0.31657945696869366), rel_half_width=np.float64(0.004542254419097131), conf_level=0.95), BER SinglePerformancePoint(event_count=458100, total_trial_count=3236872, p_hat=0.1415255221707871, ci_low=0.14114622502362784, ci_high=0.14190567017847505, rel_half_width=0.0026830678424586527, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(127511), total_trial_count=404609, p_hat=np.float64(0.31514622759256466), ci_low=np.float64(0.31371650827880543), ci_high=np.float64(0.31657945696869366), rel_half_width=np.float64(0.004542254419097131), conf_level=0.95), BER SinglePerformancePoint(event_count=458100, total_trial_count=3236872, p_hat=0.1415255221707871, ci_low=0.14114622502362784, ci_high=0.14190567017847505, rel_half_width=0.0026830678424586527, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -14 dB
#
# [INFO] --- SNR target -14.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(77677), total_trial_count=404609, p_hat=np.float64(0.19198040577446374), ci_low=np.float64(0.1907697487389228), ci_high=np.float64(0.19319691158426952), rel_half_width=np.float64(0.006321381694020694), conf_level=0.95), BER SinglePerformancePoint(event_count=258113, total_trial_count=3236872, p_hat=0.07974149116801653, ci_low=0.0794468806957942, ci_high=0.08003709914884582, rel_half_width=0.003700824027782652, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(77677), total_trial_count=404609, p_hat=np.float64(0.19198040577446374), ci_low=np.float64(0.1907697487389228), ci_high=np.float64(0.19319691158426952), rel_half_width=np.float64(0.006321381694020694), conf_level=0.95), BER SinglePerformancePoint(event_count=258113, total_trial_count=3236872, p_hat=0.07974149116801653, ci_low=0.0794468806957942, ci_high=0.08003709914884582, rel_half_width=0.003700824027782652, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -13 dB
#
# [INFO] --- SNR target -13.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(42475), total_trial_count=404609, p_hat=np.float64(0.10497789223670259), ci_low=np.float64(0.10403715236659802), ci_high=np.float64(0.10592613291253922), rel_half_width=np.float64(0.008997039784728903), conf_level=0.95), BER SinglePerformancePoint(event_count=123188, total_trial_count=3236872, p_hat=0.03805772980828405, ci_low=0.0378498373352128, ci_high=0.03826671872885308, rel_half_width=0.00547696086629868, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(42475), total_trial_count=404609, p_hat=np.float64(0.10497789223670259), ci_low=np.float64(0.10403715236659802), ci_high=np.float64(0.10592613291253922), rel_half_width=np.float64(0.008997039784728903), conf_level=0.95), BER SinglePerformancePoint(event_count=123188, total_trial_count=3236872, p_hat=0.03805772980828405, ci_low=0.0378498373352128, ci_high=0.03826671872885308, rel_half_width=0.00547696086629868, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -12 dB
#
# [INFO] --- SNR target -12.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(23151), total_trial_count=404609, p_hat=np.float64(0.05721820325301711), ci_low=np.float64(0.05650674427468947), ci_high=np.float64(0.057938069913279024), rel_half_width=np.float64(0.012507607345343195), conf_level=0.95), BER SinglePerformancePoint(event_count=56282, total_trial_count=3236872, p_hat=0.017387774369823708, ci_low=0.01724594985427859, ci_high=0.017530744394237206, rel_half_width=0.008189505278285507, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(23151), total_trial_count=404609, p_hat=np.float64(0.05721820325301711), ci_low=np.float64(0.05650674427468947), ci_high=np.float64(0.057938069913279024), rel_half_width=np.float64(0.012507607345343195), conf_level=0.95), BER SinglePerformancePoint(event_count=56282, total_trial_count=3236872, p_hat=0.017387774369823708, ci_low=0.01724594985427859, ci_high=0.017530744394237206, rel_half_width=0.008189505278285507, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -11 dB
#
# [INFO] --- SNR target -11.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(12961), total_trial_count=404609, p_hat=np.float64(0.03203339520376462), ci_low=np.float64(0.031495244770538104), ci_high=np.float64(0.032580431536090644), rel_half_width=np.float64(0.016938366330663052), conf_level=0.95), BER SinglePerformancePoint(event_count=27337, total_trial_count=3236872, p_hat=0.008445499235063976, ci_low=0.00834638987760137, ci_high=0.008545775326417721, rel_half_width=0.01180424290304501, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(12961), total_trial_count=404609, p_hat=np.float64(0.03203339520376462), ci_low=np.float64(0.031495244770538104), ci_high=np.float64(0.032580431536090644), rel_half_width=np.float64(0.016938366330663052), conf_level=0.95), BER SinglePerformancePoint(event_count=27337, total_trial_count=3236872, p_hat=0.008445499235063976, ci_low=0.00834638987760137, ci_high=0.008545775326417721, rel_half_width=0.01180424290304501, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -10 dB
#
# [INFO] --- SNR target -10.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(7412), total_trial_count=404609, p_hat=np.float64(0.018318920241517118), ci_low=np.float64(0.01791026514921195), ci_high=np.float64(0.01873672164774514), rel_half_width=np.float64(0.02255745665238907), conf_level=0.95), BER SinglePerformancePoint(event_count=14860, total_trial_count=3236872, p_hat=0.004590851908879931, ci_low=0.004517794324800674, ci_high=0.004665085376085389, rel_half_width=0.0160417994533667, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(7412), total_trial_count=404609, p_hat=np.float64(0.018318920241517118), ci_low=np.float64(0.01791026514921195), ci_high=np.float64(0.01873672164774514), rel_half_width=np.float64(0.02255745665238907), conf_level=0.95), BER SinglePerformancePoint(event_count=14860, total_trial_count=3236872, p_hat=0.004590851908879931, ci_low=0.004517794324800674, ci_high=0.004665085376085389, rel_half_width=0.0160417994533667, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -9 dB
#
# [INFO] --- SNR target -9.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(4088), total_trial_count=404609, p_hat=np.float64(0.010103581482369398), ci_low=np.float64(0.009800048503193893), ci_high=np.float64(0.01041641677093951), rel_half_width=np.float64(0.030502464340054564), conf_level=0.95), BER SinglePerformancePoint(event_count=8226, total_trial_count=3236872, p_hat=0.00254134238239881, ci_low=0.002487081160237741, ci_high=0.0025967843523190363, rel_half_width=0.021583709625490315, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(4088), total_trial_count=404609, p_hat=np.float64(0.010103581482369398), ci_low=np.float64(0.009800048503193893), ci_high=np.float64(0.01041641677093951), rel_half_width=np.float64(0.030502464340054564), conf_level=0.95), BER SinglePerformancePoint(event_count=8226, total_trial_count=3236872, p_hat=0.00254134238239881, ci_low=0.002487081160237741, ci_high=0.0025967843523190363, rel_half_width=0.021583709625490315, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -8 dB
#
# [INFO] --- SNR target -8.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(1888), total_trial_count=404609, p_hat=np.float64(0.004666233326495456), ci_low=np.float64(0.004460894784688018), ci_high=np.float64(0.004880977423797946), rel_half_width=np.float64(0.045013034038037365), conf_level=0.95), BER SinglePerformancePoint(event_count=3705, total_trial_count=3236872, p_hat=0.0011446235748586908, ci_low=0.0011083752514492924, ci_high=0.001182055961222543, rel_half_width=0.03218556361743066, conf_level=0.95), FER None
# [INFO] Total Frames: 401 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(1888), total_trial_count=404609, p_hat=np.float64(0.004666233326495456), ci_low=np.float64(0.004460894784688018), ci_high=np.float64(0.004880977423797946), rel_half_width=np.float64(0.045013034038037365), conf_level=0.95), BER SinglePerformancePoint(event_count=3705, total_trial_count=3236872, p_hat=0.0011446235748586908, ci_low=0.0011083752514492924, ci_high=0.001182055961222543, rel_half_width=0.03218556361743066, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -7 dB
#
# [INFO] --- SNR target -7.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [INFO] Trust criterion met.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(1537), total_trial_count=727489, p_hat=np.float64(0.002112746721943562), ci_low=np.float64(0.0020098319121404635), ci_high=np.float64(0.0022209196271444948), rel_half_width=np.float64(0.04995575494488213), conf_level=0.95), BER SinglePerformancePoint(event_count=3097, total_trial_count=5819912, p_hat=0.0005321386302748221, ci_low=0.0005137289886241918, ci_high=0.0005512076234604158, rel_half_width=0.03521510439569878, conf_level=0.95), FER None
# [INFO] Total Frames: 721 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(1537), total_trial_count=727489, p_hat=np.float64(0.002112746721943562), ci_low=np.float64(0.0020098319121404635), ci_high=np.float64(0.0022209196271444948), rel_half_width=np.float64(0.04995575494488213), conf_level=0.95), BER SinglePerformancePoint(event_count=3097, total_trial_count=5819912, p_hat=0.0005321386302748221, ci_low=0.0005137289886241918, ci_high=0.0005512076234604158, rel_half_width=0.03521510439569878, conf_level=0.95), FER None
#
# [INFO] Running SNR point: -6 dB
#
# [INFO] --- SNR target -6.0 dB ---
# [INFO] Minimum transceive attempts: 400
# [WARN] Trust criterion not met, but too many transceive attempts made. Moving on.
# [INFO] SER SinglePerformancePoint(event_count=np.int64(1494), total_trial_count=2018000, p_hat=np.float64(0.0007403369672943508), ci_low=np.float64(0.000703748568711801), ci_high=np.float64(0.0007788261406890905), rel_half_width=np.float64(0.05070500008372499), conf_level=0.95), BER SinglePerformancePoint(event_count=3029, total_trial_count=16144000, p_hat=0.0001876238850346878, ci_low=0.0001810606904215935, ci_high=0.00019442493993074221, rel_half_width=0.035614467493512214, conf_level=0.95), FER None
# [INFO] Total Frames: 2000 | Total FER Errors: 0
# [INFO] Final SER SinglePerformancePoint(event_count=np.int64(1494), total_trial_count=2018000, p_hat=np.float64(0.0007403369672943508), ci_low=np.float64(0.000703748568711801), ci_high=np.float64(0.0007788261406890905), rel_half_width=np.float64(0.05070500008372499), conf_level=0.95), BER SinglePerformancePoint(event_count=3029, total_trial_count=16144000, p_hat=0.0001876238850346878, ci_low=0.0001810606904215935, ci_high=0.00019442493993074221, rel_half_width=0.035614467493512214, conf_level=0.95), FER None
# [INFO] Saved performance metrics to sim_async_awgn_phase_mis/cpa/dech/profile_20251103_085002CPA.json
